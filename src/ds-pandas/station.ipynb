# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv("../../data/penguin_sector.csv", index_col=0, sep=",")

sns.scatterplot(data=df, x="x", y="z", size="size", hue="class")
# Out:
# <Axes: xlabel='x', ylabel='z'>

# %%
inspect_df = pd.read_csv("../../data/ship_inspection.csv", index_col=0, sep=",")
inspect_df.head(inspect_df.shape[0])
# Out:
#                               status  life support [%]  life forms security
# station
# bridge                            OK               100           1      red
# reactor                           OK                 0           0      red
# engines                           OK                 0           0      red
# shuttle bay                       OK               100           0     blue
# bamboo grove                      OK               100       15783    green
# waterfall         under construction                99          15    green
# shield generator                  OK               100           0   orange
# quarters                          OK               100           0    green
# cargo bay                         OK               100           0    green
# quarantine                        OK               100           0   orange
# medical                           OK               100           0     blue
# ...

# %%
inspect_df.dtypes
# Out:
# status              object
# life support [%]     int64
# life forms           int64
# security            object
# dtype: object

# %%
inspect_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18 entries, bridge to computer core
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   status            18 non-null     object
#  1   life support [%]  18 non-null     int64
#  2   life forms        18 non-null     int64
#  3   security          18 non-null     object
# dtypes: int64(2), object(2)
# memory usage: 720.0+ bytes

# %%
inspect_df["security"].value_counts()
# Out:
# orange    6
# green     5
# red       4
# blue      3
# Name: security, dtype: int64

# %%
# life forms on the bridge
inspect_df.loc["bridge"]["life forms"]
# Out:
# 1

# %%
# number of stations
inspect_df.shape[0]
# Out:
# 18

# %%
# number of unique security levels
len(inspect_df["security"].unique())
# Out:
# 4

# %%
# Life support value that is not 0 or 100
inspect_df[(inspect_df["life support [%]"] != 100) & (inspect_df["life support [%]"] != 0)]
# Or using isin
inspect_df[~inspect_df["life support [%]"].isin([0, 100])]
# Out:
#                        status  life support [%]  life forms security
# station
# waterfall  under construction                99          15    green
