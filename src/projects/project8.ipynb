# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("../../data/penguins.csv", index_col=0, sep=";")
df
# Out:
#          Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  \
# Species
# Adelie                 39.1               18.7                181.0
# Adelie                 39.5               17.4                186.0
# Adelie                 40.3               18.0                195.0
# Adelie                 36.7               19.3                193.0
# Adelie                 39.3               20.6                190.0
# ...                     ...                ...                  ...
# Gentoo                 47.2               13.7                214.0
# Gentoo                 46.8               14.3                215.0
# Gentoo                 50.4               15.7                222.0
# Gentoo                 45.2               14.8                212.0
# Gentoo                 49.9               16.1                213.0
#
#          Body Mass (g)     Sex
# Species
# Adelie          3750.0    MALE
# Adelie          3800.0  FEMALE
# Adelie          3250.0  FEMALE
# ...

# %%
import math
avg_length = math.floor(df["Culmen Length (mm)"].mean())
avg_depth = math.floor(df["Culmen Depth (mm)"].mean())

print(f"The avg penguin's culmen length = {avg_length}mm and depth = {avg_depth}mm")

fig, axs = plt.subplots(ncols=2)

sns.histplot(data=df, x="Culmen Length (mm)", kde=True, color="purple", ax=axs[0])
sns.histplot(data=df, x="Culmen Depth (mm)", kde=True, ax=axs[1])
# Out:
# The avg penguin's culmen length = 43mm and depth = 17mm
# <Axes: xlabel='Culmen Depth (mm)', ylabel='Count'>

# %% [markdown]
# ### Question 2

# %%
fig, axs = plt.subplots(ncols=2)
sns.histplot(data=df, x="Culmen Length (mm)", kde=True, ax=axs[0], hue="Species")
sns.histplot(data=df, x="Culmen Depth (mm)", kde=True, ax=axs[1], hue="Species")

plt.show()

# %% [markdown]
# ### Question 3

# %%
lengths = df.groupby(["Species"])["Culmen Length (mm)"].mean()
depths = df.groupby(["Species"])["Culmen Depth (mm)"].mean()

print(lengths)
print(depths)
# Out:
# Species
# Adelie       38.823973
# Chinstrap    48.833824
# Gentoo       47.568067
# Name: Culmen Length (mm), dtype: float64
# Species
# Adelie       18.347260
# Chinstrap    18.420588
# Gentoo       14.996639
# Name: Culmen Depth (mm), dtype: float64

# %% [markdown]
# Based on the data above, it is evident that the Gentoos have long (47.6mm) and slim (14.9mm) beaks, while the Adelies have short (38.8mm) and wide (18.3mm) beaks.

# %% [markdown]
# ### Question 4

# %%
df.index.value_counts()
# Out:
# Adelie       146
# Gentoo       119
# Chinstrap     68
# Name: Species, dtype: int64

# %% [markdown]
# Evidently, Adelie is the most prevalant species.

# %%
sns.histplot(data=df, x="Body Mass (g)", hue="Species", kde=True)
# Out:
# <Axes: xlabel='Body Mass (g)', ylabel='Count'>

# %% [markdown]
# Based on the graph above as well as our observation from Question 3, we can conclude that Adelies (which are the most prevalant species), normally tend to have a larger body mass than the other two species and they also have shorter and wider beaks.
